# %% [markdown]
# #Correlations of Composition, Structure, and Hardness in the High-Entropy Alloy System Nb–Mo–Ta–W

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#importing libraries
import pandas as pd

# Load data
data = pd.read_csv('/content/Copy of MoNbTaW_preprocessed_features - MoNbTaW_preprocessed_features.csv')  # assuming data is stored in a CSV file
data.head()
# Out:
#      Mo    Nb    Ta     W   sigma_T     x     y  reduced modulus       E_ROM  \
# 0  16.2  33.9  37.3  12.6  0.856579 -22.5 -40.5           107.54  210.057000
# 1  16.3  35.7  34.9  13.1  0.864383 -18.0 -40.5           108.01  209.867000
# 2  16.1  37.8  32.4  13.8  0.866180 -13.5 -40.5           113.82  209.431568
# 3  15.0  40.1  30.6  14.3  0.843410  -9.0 -40.5           113.59  207.144000
# 4  15.3  41.6  28.7  14.5  0.848367  -4.5 -40.5           118.49  206.787213
#
#       C11_ROM     C12_ROM    C44_ROM  shear_modulus_from_ROM  \
# 0  319.231400  151.456000  78.395000               81.094860
# 1  320.385100  151.206000  77.821000               81.134724
# 2  321.330370  150.963037  77.165834               81.075697
# 3  320.001000  150.522000  75.999000               80.250341
# 4  320.775325  150.217782  75.415584               80.195688
#
#    bulk_modulus_from_ROM      V_ROM    dV_ROM    HV_ROM     a_ROM     b_ROM  \
# ...

# %%
data.describe()
# Out:
#                Mo          Nb          Ta           W     sigma_T           x  \
# count  311.000000  311.000000  311.000000  311.000000  311.000000  311.000000
# mean    19.586495   36.501929   23.959164   19.953376    1.070883   -3.950161
# std      5.142111    9.127435    7.423227    4.880274    0.169500   21.376500
# min      9.800000   20.400000   12.500000   12.300000    0.703809  -45.000000
# 25%     15.550000   28.850000   17.700000   16.000000    0.941291  -22.500000
# 50%     19.000000   35.700000   22.600000   18.900000    1.077116   -4.500000
# 75%     23.350000   43.450000   29.300000   23.200000    1.214813   13.500000
# max     31.300000   57.200000   42.000000   32.400000    1.373801   31.500000
#
#                 y  reduced modulus       E_ROM     C11_ROM     C12_ROM  \
# count  311.000000       311.000000  311.000000  311.000000  311.000000
# mean     1.012862       139.577235  229.337737  344.875162  154.539808
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Mo                      311 non-null    float64
#  1   Nb                      311 non-null    float64
#  2   Ta                      311 non-null    float64
#  3   W                       311 non-null    float64
#  4   sigma_T                 311 non-null    float64
#  5   x                       311 non-null    float64
#  6   y                       311 non-null    float64
#  7   reduced modulus         311 non-null    float64
#  8   E_ROM                   311 non-null    float64
#  9   C11_ROM                 311 non-null    float64
#  10  C12_ROM                 311 non-null    float64
#  11  C44_ROM                 311 non-null    float64
#  12  shear_modulus_from_ROM  311 non-null    float64
#  13  bulk_modulus_from_ROM   311 non-null    float64
# ...

# %% [markdown]
# #Graph between Hardness and Elements

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#graph between Hardness and other parameters
sns.pairplot(data, x_vars=['Mo', 'Nb', 'Ta', 'W'], y_vars='hardness', kind='scatter', diag_kind=None)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.pairplot(data, x_vars=['reduced modulus', 'E_ROM'], y_vars='hardness', kind='scatter', diag_kind=None)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.pairplot(data, x_vars=['C11_ROM','C12_ROM', 'C44_ROM'], y_vars='hardness', kind='scatter', diag_kind=None)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.pairplot(data, x_vars=['shear_modulus_from_ROM', 'bulk_modulus_from_ROM'], y_vars='hardness', kind='scatter', diag_kind=None)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
